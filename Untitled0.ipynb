# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanSmalhotra/AIML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import hashlib
import getpass

# Function to create a database and user table
def create_table():
    try:
        conn = sqlite3.connect('users.db')
        c = conn.cursor()
        c.execute('''CREATE TABLE IF NOT EXISTS users 
                     (username TEXT, password TEXT)''')
        conn.commit()
    except:
        print("Error creating database")
    finally:
        conn.close()

# Function to add a new user to the database
def add_user(username, password):
    try:
        conn = sqlite3.connect('users.db')
        c = conn.cursor()
        hashed_password = hashlib.sha256(password.encode('utf-8')).hexdigest()
        c.execute('''INSERT INTO users (username, password) 
                     VALUES (?, ?)''', (username, hashed_password))
        conn.commit()
        print('Account created successfully.')
    except:
        print("Error adding user to database")
    finally:
        conn.close()

# Function to check if a user exists in the database
def user_exists(username):
    try:
        conn = sqlite3.connect('users.db')
        c = conn.cursor()
        c.execute('''SELECT * FROM users WHERE username = ?''', (username,))
        result = c.fetchone()
        return result != None
    except:
        print("Error checking if user exists in database")
    finally:
        conn.close()

# Function to check if a username and password match
def check_login(username, password):
    try:
        conn = sqlite3.connect('users.db')
        c = conn.cursor()
        hashed_password = hashlib.sha256(password.encode('utf-8')).hexdigest()
        c.execute('''SELECT * FROM users WHERE username = ? AND password = ?''', 
                  (username, hashed_password))
        result = c.fetchone()
        return result != None
    except:
        print("Error checking login credentials")
    finally:
        conn.close()

# Create the database table
create_table()

# Sign up page
def signup():
    while True:
        username = input('Enter your username: ')
        if user_exists(username):
            print('Username already exists. Please try again.')
        else:
            break
    while True:
        password = getpass.getpass('Enter your password: ')
        if len(password) < 8:
            print('Password must be at least 8 characters. Please try again.')
        else:
            break
    add_user(username, password)

# Login page
def login():
    username = input('Enter your username: ')
    password = getpass.getpass('Enter your password: ')
    if check_login(username, password):
        print('Login successful!')
    else:
        print('Incorrect username or password.')

# User interface
while True:
    print('1. Sign up')
    print('2. Login')
    print('3. Exit')
    choice = input('Enter your choice: ')
    if choice == '1':
        signup()
    elif choice == '2':
        login()
    elif choice == '3':
        break
    else:
        print('Invalid choice. Please try again.')
# Out:
# 1. Sign up
# 2. Login
# 3. Exit
# Enter your choice: 1
# Enter your username: Aryan
# Enter your password: ··········
# Account created successfully.
# 1. Sign up
# 2. Login
# 3. Exit
# Enter your choice: 1
# Enter your username: Aryan
# Username already exists. Please try again.
# Enter your username: ImDumDum
# Enter your password: ··········
# Password must be at least 8 characters. Please try again.
# Enter your password: ··········
# Account created successfully.
# 1. Sign up
# 2. Login
# 3. Exit
# Enter your choice: 2
# Enter your username: Aryan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-96fc62c0c6f8> in <cell line: 91>()
#      96         signup()
#      97     elif choice == '2':
# ---> 98         login()
#      99     elif choice == '3':
#     100         break
#
# <ipython-input-2-96fc62c0c6f8> in login()
#      81 def login():
# ...

# %%
import sqlite3
import hashlib
import getpass

# Function to create a database and user table
def create_table():
    conn = sqlite3.connect('users.db')
    c = conn.cursor()
    c.execute('''CREATE TABLE IF NOT EXISTS users 
                 (username TEXT, password TEXT)''')
    conn.commit()
    conn.close()

# Function to add a new user to the database
def add_user(username, password):
    conn = sqlite3.connect('users.db')
    c = conn.cursor()
    
    # Hash the password before storing it
    hashed_password = hashlib.sha256(password.encode('utf-8')).hexdigest()
    
    c.execute('''INSERT INTO users (username, password) 
                 VALUES (?, ?)''', (username, hashed_password))
    conn.commit()
    conn.close()

# Function to check if a user exists in the database
def user_exists(username):
    conn = sqlite3.connect('users.db')
    c = conn.cursor()
    c.execute('''SELECT * FROM users WHERE username = ?''', (username,))
    result = c.fetchone()
    conn.close()
    return result != None

# Function to check if a username and password match
def check_login(username, password):
    conn = sqlite3.connect('users.db')
    c = conn.cursor()
    
    # Hash the password before comparing it to the stored hash
    hashed_password = hashlib.sha256(password.encode('utf-8')).hexdigest()
    
    c.execute('''SELECT * FROM users WHERE username = ? AND password = ?''', 
              (username, hashed_password))
    result = c.fetchone()
    conn.close()
    return result != None

# Create the database table
create_table()

# Sign up page
def signup():
    while True:
        username = input('Enter your username: ')
        if user_exists(username):
            print('Username already exists. Please try again.')
        else:
            break
    
    while True:
        password = getpass.getpass('Enter your password: ')
        if len(password) < 8:
            print('Password must be at least 8 characters long. Please try again.')
        else:
            break
    
    add_user(username, password)
    print('Account created successfully.')

# Login page
def login():
    username = input('Enter your username: ')
    password = getpass.getpass('Enter your password: ')
    if check_login(username, password):
        print('Login successful!')
    else:
        print('Incorrect username or password.')

# User interface
while True:
    print('1. Sign up')
    print('2. Login')
    print('3. Exit')
    choice = input('Enter your choice: ')
    if choice == '1':
        signup()
    elif choice == '2':
        login()
    elif choice == '3':
        break
    else:
        print('Invalid choice. Please try again.')
# Out:
# 1. Sign up
# 2. Login
# 3. Exit
# Enter your choice: 1
# Enter your username: AryanS
# Enter your password: ··········
# Account created successfully.
# 1. Sign up
# 2. Login
# 3. Exit
# Enter your choice: 2
# Enter your username: AryanS
# Enter your password: ··········
# Incorrect username or password.
# 1. Sign up
# 2. Login
# 3. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9f1cbd4da81a> in <cell line: 83>()
#      84     print('2. Login')
#      85     print('3. Exit')
# ---> 86     choice = input('Enter your choice: ')
#      87     if choice == '1':
#      88         signup()
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# ...

# %%
import sqlite3
import getpass
import string
import random
import hashlib

# Function to create a database and user table
def create_table():
    conn = sqlite3.connect('users.db')
    c = conn.cursor()
    c.execute('''CREATE TABLE IF NOT EXISTS users 
                 (username TEXT, password TEXT, except_policy INTEGER)''')
    conn.commit()
    conn.close()

# Function to add a new user to the database
def add_user(username, password, except_policy):
    conn = sqlite3.connect('users.db')
    c = conn.cursor()
    c.execute('''INSERT INTO users (username, password, except_policy) 
                 VALUES (?, ?, ?)''', (username, password, except_policy))
    conn.commit()
    conn.close()

# Function to check if a user exists in the database
def user_exists(username):
    conn = sqlite3.connect('users.db')
    c = conn.cursor()
    c.execute('''SELECT * FROM users WHERE username = ?''', (username,))
    result = c.fetchone()
    conn.close()
    return result != None

# Function to check if a username and password match
def check_login(username, password):
    conn = sqlite3.connect('users.db')
    c = conn.cursor()
    c.execute('''SELECT * FROM users WHERE username = ? AND password = ?''', 
              (username, password))
    result = c.fetchone()
    conn.close()
    return result != None

# Function to generate a strong password
def generate_password():
    length = 12
    while True:
        password = ''.join(random.choice(string.ascii_letters + string.digits) for _ in range(length))
        if any(c.islower() for c in password) and any(c.isupper() for c in password) and any(c.isdigit() for c in password):
            return password

# Function to hash the password using SHA-256
def hash_password(password):
    salt = b'\x12\x8d\xd9\x9b\xefP\x8e\xaa\xb3\xb3\xb7x\x12\xd3M\x10\xca^\xae\xbb\xcf\x1e\xb1l\x96:\xf8\xe8\xa7\xc8\x1b'
    password_hash = hashlib.pbkdf2_hmac('sha256', password.encode('utf-8'), salt, 100000)
    return password_hash.hex()

# Create the database table
create_table()

# Sign up page
def signup():
    while True:
        username = input('Enter your username: ')
        if not all(c.isalnum() or c.isspace() for c in username):
            print('Username can only contain alphanumeric characters and spaces. Please try again.')
        elif user_exists(username):
            print('Username already exists. Please try again.')
        else:
            break
    
    while True:
        password = getpass.getpass('Enter your password: ')
        if len(password) < 8:
            print('Password must be at least 8 characters long. Please try again.')
        elif password.isalpha() or password.isdigit() or password.islower() or password.isupper():
            print('Password must contain at least one lowercase letter, one uppercase letter, and one digit. Please try again.')
        else:
            break
    
    while True:
        except_policy = input('Do you want to opt for exception policy? (yes/no): ')
        if except_policy.lower() == 'yes':
            except_policy = 1
            break
        elif except_policy.lower() == 'no':
            except_policy = 0
            break
        else:
            print('Invalid')

# %%
import sqlite3
import getpass
import string
import random
import hashlib

# Function to create a database and user table
def create_table():
    conn = sqlite3.connect('users.db')
    c = conn.cursor()
    c.execute('''CREATE TABLE IF NOT EXISTS users 
                 (username TEXT, password TEXT, except_policy INTEGER)''')
    conn.commit()
    conn.close()

# Function to add a new user to the database
def add_user(username, password, except_policy):
    conn = sqlite3.connect('users.db')
    c = conn.cursor()
    c.execute('''INSERT INTO users (username, password, except_policy) 
                 VALUES (?, ?, ?)''', (username, password, except_policy))
    conn.commit()
    conn.close()

# Function to check if a user exists in the database
def user_exists(username):
    conn = sqlite3.connect('users.db')
    c = conn.cursor()
    c.execute('''SELECT * FROM users WHERE username = ?''', (username,))
    result = c.fetchone()
    conn.close()
    return result != None

# Function to check if a username and password match
def check_login(username, password):
    conn = sqlite3.connect('users.db')
    c = conn.cursor()
    c.execute('''SELECT * FROM users WHERE username = ? AND password = ?''', 
              (username, password))
    result = c.fetchone()
    conn.close()
    return result != None

# Function to generate a strong password
def generate_password():
    length = 12
    while True:
        password = ''.join(random.choice(string.ascii_letters + string.digits) for _ in range(length))
        if any(c.islower() for c in password) and any(c.isupper() for c in password) and any(c.isdigit() for c in password):
            return password

# Function to hash the password using SHA-256
def hash_password(password):
    salt = b'\x12\x8d\xd9\x9b\xefP\x8e\xaa\xb3\xb3\xb7x\x12\xd3M\x10\xca^\xae\xbb\xcf\x1e\xb1l\x96:\xf8\xe8\xa7\xc8\x1b'
    password_hash = hashlib.pbkdf2_hmac('sha256', password.encode('utf-8'), salt, 100000)
    return password_hash.hex()

# Create the database table
create_table()

# Sign up page
def signup():
    while True:
        username = input('Enter your username: ')
        if not all(c.isalnum() or c.isspace() for c in username):
            print('Username can only contain alphanumeric characters and spaces. Please try again.')
        elif user_exists(username):
            print('Username already exists. Please try again.')
        else:
            break
    
    while True:
        password = getpass.getpass('Enter your password: ')
        if len(password) < 8:
            print('Password must be at least 8 characters long. Please try again.')
        elif password.isalpha() or password.isdigit() or password.islower() or password.isupper():
            print('Password must contain at least one lowercase letter, one uppercase letter, and one digit. Please try again.')
        else:
            break
    
    while True:
        except_policy = input('Do you want to opt for exception policy? (yes/no): ')
        if except_policy.lower() == 'yes':
            except_policy = 1
            break
        elif except_policy.lower() == 'no':
            except_policy = 0
            break
        else:
            print('Invalid')

# %%
sign up
